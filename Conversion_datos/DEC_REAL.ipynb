# %%
# ============================================================================
# Escalar datos de la onda Decimal a su valor Real
# ============================================================================

Factor_escalado = 25
Escala = 1
Dato = 50

Dato_escalado = Dato / Factor_escalado * Escala

print(f"Dato Escalado: {Dato_escalado}")
print(f"Dato Onda 2 escalado: {50/25*1}")
# Out:
# Dato Escalado: 2.0
# Dato Onda 2 escalado: 2.0
