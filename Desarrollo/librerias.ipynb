# %%
# ============================================================================
# INSTALACIÓN DE DEPENDENCIAS
# ============================================================================
# Estas librerías son necesarias para la comunicación VISA:
# - pyvisa: Interface principal para comunicación con instrumentos.
# - pyvisa-py: Backend puro de Python (no requiere VISA runtime).
# - pyserial: Para comunicación serial (usado por pyvisa-py).
# - numpy: Manejo de arrays y cálculos numéricos.
# - matplotlib: Visualización de datos.
# - pandas: Manipulación y análisis de datos.
# - h5py: Lectura y escritura de archivos HDF5.


# %pip install pyvisa pyvisa-py pyserial numpy scipy matplotlib pandas h5py pytest
# Out:
# Requirement already satisfied: pyvisa in d:\repositorios git\pi\.venv\lib\site-packages (1.15.0)
# Requirement already satisfied: pyvisa-py in d:\repositorios git\pi\.venv\lib\site-packages (0.8.1)
# Requirement already satisfied: pyserial in d:\repositorios git\pi\.venv\lib\site-packages (3.5)
# Requirement already satisfied: numpy in d:\repositorios git\pi\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: scipy in d:\repositorios git\pi\.venv\lib\site-packages (1.16.3)
# Requirement already satisfied: matplotlib in d:\repositorios git\pi\.venv\lib\site-packages (3.10.7)
# Requirement already satisfied: pandas in d:\repositorios git\pi\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: h5py in d:\repositorios git\pi\.venv\lib\site-packages (3.15.1)
# Requirement already satisfied: typing_extensions>=4.0.0 in d:\repositorios git\pi\.venv\lib\site-packages (from pyvisa) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\repositorios git\pi\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\repositorios git\pi\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\repositorios git\pi\.venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\repositorios git\pi\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\repositorios git\pi\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\repositorios git\pi\.venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in d:\repositorios git\pi\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in d:\repositorios git\pi\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\repositorios git\pi\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\repositorios git\pi\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\repositorios git\pi\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
