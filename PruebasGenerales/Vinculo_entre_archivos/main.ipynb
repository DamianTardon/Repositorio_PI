# %%
import suma
#from suma import sumar

if __name__ == '__main__':
    resultado = suma.sumar(5, 6)
    #resultado = sumar(3, 5)
    print(f'El resultado de la suma es: {resultado}')
# Out:
# El resultado de la suma es: 11
